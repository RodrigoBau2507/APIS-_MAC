# %% [markdown]
# # Bautista Rodriguez Rodrigo

# %% [markdown]
# ## APIx for Dummies: Learning About APIs

# %% [markdown]
# * ¿Qué es una API?
#   - Una API (interfaz de programación de aplicaciones) actúa como mensajero entre diferentes componentes de software. Les permite comunicarse e intercambiar datos. Las API son como los camareros de un restaurante: reciben solicitudes de una parte (el cliente) y las entregan a otra (el servidor), y luego devuelven la respuesta.
#
# * ¿Por qué son importantes las API?
#   - Las API son esenciales para crear software moderno. Permiten que diferentes aplicaciones funcionen juntas sin problemas, creando soluciones más potentes. Éstos son algunos de los beneficios clave:
#     - Flujo de datos entre sistemas: las API permiten que los datos se transfieran entre diferentes programas de software, lo que les permite basarse entre sí.
#     - Automatización: las API pueden automatizar tareas complejas combinando funcionalidades de varias API en una sola aplicación.
#     - Fácil integración: las API facilitan a los desarrolladores la integración de herramientas y servicios externos en sus aplicaciones.
#     - Valor empresarial: las API pueden ser un activo valioso para las empresas al hacer que sus plataformas sean más abiertas y accesibles para otros desarrolladores.
#
# * Tipos de API
#   - Existen varios tipos diferentes de API, cada una con sus propias características:
#     * REST: Este es el tipo más común de API. Utiliza verbos HTTP (GET, POST, PUT, DELETE) para interactuar con recursos representados por URL.
#     * SOAP: SOAP es una especificación más formal para compartir datos que utiliza XML para el intercambio de datos.
#     * GraphQL: esta es una tecnología más nueva diseñada para abordar las limitaciones de REST y SOAP. Permite a los clientes especificar exactamente los datos que necesitan, reduciendo la transferencia de datos innecesaria.
#     * RPC (llamadas a procedimientos remotos): una forma simple de API donde un cliente llama a una función en un servidor remoto como si fuera local.
#     * API del sistema: estas API brindan acceso a funciones de un sistema operativo específico (por ejemplo, notificaciones, reproducción multimedia).
#     * API de lenguajes de programación: los lenguajes de programación y las bibliotecas también tienen API que definen cómo interactúan los diferentes componentes dentro del código.
#
# - Cómo funcionan las API
#   - Cada tipo de API tiene su propia forma de estructurar la comunicación. Aquí hay un vistazo a REST y GraphQL como ejemplos:
#     * REST: REST utiliza verbos HTTP y URL para realizar acciones en los recursos. Por ejemplo, GET /users/100 recupera datos de usuario con ID 100, mientras que DELETE /users/100 elimina ese usuario.
#     * GraphQL: GraphQL utiliza un lenguaje de consulta que permite a los clientes solicitar campos de datos específicos. Esto evita la transferencia de datos innecesarios en comparación con REST.

# %% [markdown]
# ## API de Libros

# %%
import requests
import json
import pandas as pd

# %%
# Funcion 

def consumo_API(url_api):
    response = requests.get(url_api)
    result = json.loads(response.text)
    resultados = result['data']
    pd.DataFrame(resultados)
    return resultados

# %%
libros =  consumo_API("https://fakerapi.it/api/v1/books?")
pd.DataFrame(libros)
# Out:
#    id                title           author        genre  \
# 0   1   Alice. 'I've read.     Aiden Herzog  Consectetur
# 1   2  Mock Turtle: 'nine.    Kenyon Deckow           Ut
# 2   3     Oh dear! I wish.    Erin Baumbach         Quas
# 3   4     Alice. The King.   Edwin Homenick      Eveniet
# 4   5  Let me see--how IS.       Laila Kihn       Magnam
# 5   6    Some of the sort.    Marlon Muller          Sit
# 6   7     Queen in a more.       Gail Ratke     Delectus
# 7   8   Cat, 'a dog's not.  Buford Johnston      Facilis
# 8   9         Latitude or.      Emely Brown         Ipsa
# 9  10     I used to queer.  Eusebio Hegmann     Mollitia
#
#                                          description           isbn  \
# 0  YET,' she said to the Gryphon. 'Do you take me...  9787178020962
# 1  Dormouse,' thought Alice; 'I daresay it's a Fr...  9792284726349
# 2  Queen shrieked out. 'Behead that Dormouse! Tur...  9798803684879
# 3  Queen: so she helped herself to some tea and b...  9783366523666
# 4  Rabbit came near her, about the whiting!' 'Oh,...  9793832899508
# 5  Alice hastily replied; 'only one doesn't like ...  9797793939174
# 6  Alice waited patiently until it chose to speak...  9789058060976
# 7  I only knew how to spell 'stupid,' and that he...  9796263928632
# 8  White Rabbit. She was a most extraordinary noi...  9786509616096
# 9  Time, and round Alice, every now and then at t...  9793818322624
#
#                              image   published           publisher
# 0  http://placeimg.com/480/640/any  1988-02-12     Modi Temporibus
# 1  http://placeimg.com/480/640/any  2022-06-07               Ea Et
# 2  http://placeimg.com/480/640/any  1986-08-01            Sunt Eos
# 3  http://placeimg.com/480/640/any  1993-07-22          Tempore Ea
# 4  http://placeimg.com/480/640/any  1973-09-26        Quia Numquam
# 5  http://placeimg.com/480/640/any  1995-12-23        Non Mollitia
# 6  http://placeimg.com/480/640/any  2015-02-06         Eligendi Et
# 7  http://placeimg.com/480/640/any  1992-07-25         Ullam Saepe
# 8  http://placeimg.com/480/640/any  1984-05-09             Ipsa Ut
# 9  http://placeimg.com/480/640/any  1974-10-20  Numquam Asperiores

# %% [markdown]
# ## API de Credit Cards

# %%
Cards =  consumo_API('https://fakerapi.it/api/v1/credit_cards?')
pd.DataFrame(Cards)
# Out:
#                type            number expiration                owner
# 0              Visa  5219876653170752      03/25          Lonzo Upton
# 1        MasterCard  2492923944259856      08/26       Yadira Effertz
# 2              Visa  4716407711424527      01/26       Stephan Kuphal
# 3        MasterCard  2520724431364191      04/25     Beatrice Douglas
# 4              Visa  2221407380827101      03/27     Bryana Romaguera
# 5      Visa Retired  4556570618408506      09/26  Jaquelin Macejkovic
# 6      Visa Retired  4532559489326425      09/24        Malvina Ortiz
# 7  American Express  5274533084006608      12/24        Isabella Veum
# 8              Visa     4485569254054      02/26      Pink Williamson
# 9        MasterCard  4716437334469690      03/27           Juwan West

# %% [markdown]
# ## API de productos

# %%
productos =  consumo_API('https://fakerapi.it/api/v1/products')
pd.DataFrame(productos)
# Out:
#    id                          name  \
# 0   1  Eveniet culpa sint animi ex.
# 1   2             Et et aut et qui.
# 2   3     Eveniet alias rerum sunt.
# 3   4           Vel et in nesciunt.
# 4   5       Ut et harum nemo ipsam.
# 5   6          Eum aut sed quaerat.
# 6   7        Qui explicabo quas ut.
# 7   8         Quia ratione modi ex.
# 8   9        Dolores et omnis quam.
# 9  10      Quam est veniam quas ut.
#
#                                          description            ean  \
# 0  Dolor aliquam dolores non sit iure eum. Magnam...  3614285545919
# 1  Nihil illum aut laborum cumque autem et sint. ...  6608804606776
# 2  Nesciunt consequuntur illo veritatis consequat...  7696564476974
# 3  Suscipit omnis porro earum omnis iste aut et. ...  7407892188220
# 4  Esse est quis unde est sint maxime in laudanti...  3748241655043
# 5  Nihil dolore fuga corporis omnis non ullam. Qu...  9890329275460
# 6  Quo impedit vel id. Vel exercitationem amet id...  2338807409961
# 7  Sint ullam eos doloremque. Assumenda est ut at...  8753314120118
# 8  Totam quasi ut eum sed. Expedita quas dicta au...  7787191610289
# 9  Aut eum voluptatibus et totam. Dolorum ut assu...  6568869770655
#
#             upc                             image  \
# 0  197004577337  http://placeimg.com/640/480/tech
# 1  245497801364  http://placeimg.com/640/480/tech
# 2  003719876553  http://placeimg.com/640/480/tech
# 3  768677789024  http://placeimg.com/640/480/tech
# 4  757538794254  http://placeimg.com/640/480/tech
# 5  640444576322  http://placeimg.com/640/480/tech
# 6  572743606206  http://placeimg.com/640/480/tech
# 7  580125166992  http://placeimg.com/640/480/tech
# 8  898256098648  http://placeimg.com/640/480/tech
# 9  051456315758  http://placeimg.com/640/480/tech
#
#                                               images   net_price  taxes  \
# 0  [{'title': 'Earum eaque rerum ut aut et.', 'de...      386.51     22
# 1  [{'title': 'Et rerum minus beatae.', 'descript...      343.86     22
# 2  [{'title': 'Molestiae eos omnis qui et.', 'des...      316.60     22
# 3  [{'title': 'Minima numquam est sequi.', 'descr...     5750.21     22
# 4  [{'title': 'Impedit eos odit sunt.', 'descript...        4.34     22
# 5  [{'title': 'Animi et quae aut facilis.', 'desc...       42.88     22
# 6  [{'title': 'Harum saepe corrupti ea illo.', 'd...        2.96     22
# 7  [{'title': 'Et fugiat maxime aut sit.', 'descr...  1356572.30     22
# 8  [{'title': 'In soluta quia dolorem.', 'descrip...   161609.11     22
# 9  [{'title': 'Et ipsam et sequi.', 'description'...    90000.23     22
#
#         price          categories  \
# 0      471.54        [7, 8, 3, 1]
# 1      419.51           [4, 5, 3]
# 2      386.25                 [8]
# 3     7015.26                 [2]
# 4        5.29              [7, 3]
# 5       52.31     [7, 4, 9, 8, 1]
# 6        3.61        [5, 8, 6, 1]
# 7  1655018.21              [5, 9]
# 8   197163.11  [2, 6, 1, 8, 3, 9]
# 9   109800.28  [4, 6, 8, 5, 1, 2]
#
#                                                 tags
# 0                                         [possimus]
# 1                  [ea, nostrum, laborum, odit, qui]
# 2                                       [cum, nihil]
# 3            [sapiente, aliquam, ea, aliquam, ullam]
# 4            [dolor, et, odio, doloremque, ea, quas]
# 5  [in, quaerat, debitis, sed, id, quae, repellen...
# 6        [aut, aspernatur, vel, est, officia, alias]
# 7                   [fuga, dolor, dolorem, suscipit]
# 8  [ratione, et, debitis, culpa, praesentium, mol...
# 9  [sed, inventore, accusamus, tempora, ullam, am...

# %% [markdown]
# ## API Imagenes

# %%
Imagenes =  consumo_API('https://fakerapi.it/api/v1/images')
pd.DataFrame(Imagenes)
# Out:
#                            title  \
# 0  Nostrum et aut dolorem iusto.
# 1    Quo quaerat aut reiciendis.
# 2     Sed facere est fugit enim.
# 3  Aut distinctio voluptas sint.
# 4     Facilis at quae quia unde.
# 5        Ut iure officia et quo.
# 6  A accusamus vel et provident.
# 7     Natus sint quo in dolores.
# 8   Animi et qui cupiditate qui.
# 9        Eum sed velit deleniti.
#
#                                          description  \
# 0  Assumenda at ut at facere. Quo optio sequi qui...
# 1  Nostrum vitae odio perferendis provident modi ...
# 2  Est et quibusdam vel aut. Ipsum debitis mollit...
# 3  Nisi neque commodi omnis facilis voluptatem no...
# 4  Vitae ut dolor corporis et. Iste maxime eum sa...
# 5  Cum tempore aliquid maxime sunt laboriosam ill...
# 6  Reiciendis ipsam unde et. Iure quis id modi. U...
# 7  Voluptatibus rerum veritatis beatae et provide...
# 8  Perspiciatis in tempora odit enim omnis a. Dol...
# 9  Eum ut rerum numquam necessitatibus repellat n...
#
#                                url
# 0  http://placeimg.com/640/480/any
# 1  http://placeimg.com/640/480/any
# 2  http://placeimg.com/640/480/any
# 3  http://placeimg.com/640/480/any
# 4  http://placeimg.com/640/480/any
# 5  http://placeimg.com/640/480/any
# 6  http://placeimg.com/640/480/any
# 7  http://placeimg.com/640/480/any
# 8  http://placeimg.com/640/480/any
# 9  http://placeimg.com/640/480/any
