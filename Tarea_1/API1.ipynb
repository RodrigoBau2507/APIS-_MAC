# %% [markdown]
# # Bautista Rodriguez Rodrigo

# %% [markdown]
# ## APIx for Dummies: Learning About APIs

# %% [markdown]
# * ¿Qué es una API?
#   - Una API (interfaz de programación de aplicaciones) actúa como mensajero entre diferentes componentes de software. Les permite comunicarse e intercambiar datos. Las API son como los camareros de un restaurante: reciben solicitudes de una parte (el cliente) y las entregan a otra (el servidor), y luego devuelven la respuesta.
#
# * ¿Por qué son importantes las API?
#   - Las API son esenciales para crear software moderno. Permiten que diferentes aplicaciones funcionen juntas sin problemas, creando soluciones más potentes. Éstos son algunos de los beneficios clave:
#     - Flujo de datos entre sistemas: las API permiten que los datos se transfieran entre diferentes programas de software, lo que les permite basarse entre sí.
#     - Automatización: las API pueden automatizar tareas complejas combinando funcionalidades de varias API en una sola aplicación.
#     - Fácil integración: las API facilitan a los desarrolladores la integración de herramientas y servicios externos en sus aplicaciones.
#     - Valor empresarial: las API pueden ser un activo valioso para las empresas al hacer que sus plataformas sean más abiertas y accesibles para otros desarrolladores.
#
# * Tipos de API
#   - Existen varios tipos diferentes de API, cada una con sus propias características:
#     * REST: Este es el tipo más común de API. Utiliza verbos HTTP (GET, POST, PUT, DELETE) para interactuar con recursos representados por URL.
#     * SOAP: SOAP es una especificación más formal para compartir datos que utiliza XML para el intercambio de datos.
#     * GraphQL: esta es una tecnología más nueva diseñada para abordar las limitaciones de REST y SOAP. Permite a los clientes especificar exactamente los datos que necesitan, reduciendo la transferencia de datos innecesaria.
#     * RPC (llamadas a procedimientos remotos): una forma simple de API donde un cliente llama a una función en un servidor remoto como si fuera local.
#     * API del sistema: estas API brindan acceso a funciones de un sistema operativo específico (por ejemplo, notificaciones, reproducción multimedia).
#     * API de lenguajes de programación: los lenguajes de programación y las bibliotecas también tienen API que definen cómo interactúan los diferentes componentes dentro del código.
#
# - Cómo funcionan las API
#   - Cada tipo de API tiene su propia forma de estructurar la comunicación. Aquí hay un vistazo a REST y GraphQL como ejemplos:
#     * REST: REST utiliza verbos HTTP y URL para realizar acciones en los recursos. Por ejemplo, GET /users/100 recupera datos de usuario con ID 100, mientras que DELETE /users/100 elimina ese usuario.
#     * GraphQL: GraphQL utiliza un lenguaje de consulta que permite a los clientes solicitar campos de datos específicos. Esto evita la transferencia de datos innecesarios en comparación con REST.

# %% [markdown]
# ## API de Libros

# %%
import requests
import json
import pandas as pd

# %%
url_api = 'https://fakerapi.it/api/v1/books?'

# %%
response = requests.get(url_api)
result = json.loads(response.text)

# %%
book = result['data']
pd.DataFrame(book)
# Out:
#    id                title            author     genre  \
# 0   1          Alice said.   Emilie Mitchell    Magnam
# 1   2    All the time she.   Jedediah Barton     Animi
# 2   3         YOU?' Which.   Carli Powlowski  Nesciunt
# 3   4      The long grass.   Corene Schuster  Sapiente
# 4   5  Caterpillar. Alice.          Lori Von   Ratione
# 5   6     WOULD put their.      Coby Cormier        Ut
# 6   7    Who ever saw one.  Daniella Windler   Facilis
# 7   8   Lobster Quadrille.    Garland Dooley   Dolorum
# 8   9     ME, and told me.    Madisyn Casper    Maxime
# 9  10  Alice noticed with.       Dane Hudson      Esse
#
#                                          description           isbn  \
# 0  Queen, but she got up, and there was nothing o...  9797421465532
# 1  Alice, timidly; 'some of the baby?' said the M...  9796110097559
# 2  Canary called out in a loud, indignant voice, ...  9783479921595
# 3  King put on one side, to look at the beginning...  9781963804652
# 4  There was a treacle-well.' 'There's no sort of...  9783685523156
# 5  Rabbit in a piteous tone. And she began nibbli...  9794279097977
# 6  Cat, 'if you only walk long enough.' Alice fel...  9786901812256
# 7  MUST be more to be a LITTLE larger, sir, if yo...  9786788771073
# 8  There was a real nose; also its eyes were look...  9784842931470
# 9  Soup! Soup of the baby, it was over at last: '...  9783889536105
#
#                              image   published                  publisher
# 0  http://placeimg.com/480/640/any  2010-02-23                Facilis Aut
# 1  http://placeimg.com/480/640/any  2007-03-10            Optio Occaecati
# 2  http://placeimg.com/480/640/any  2021-07-12              Quae Nesciunt
# 3  http://placeimg.com/480/640/any  2014-07-17               Nihil Itaque
# 4  http://placeimg.com/480/640/any  2015-11-20           Voluptas Tempora
# 5  http://placeimg.com/480/640/any  1976-05-03          Perferendis Rerum
# 6  http://placeimg.com/480/640/any  2000-04-30  Necessitatibus Voluptatem
# 7  http://placeimg.com/480/640/any  2007-04-09                   Fuga Qui
# 8  http://placeimg.com/480/640/any  2007-11-13     Voluptates Consectetur
# 9  http://placeimg.com/480/640/any  1976-06-07                     Quia A

# %% [markdown]
# ## API de Credit Cards

# %%
url_api_cards = 'https://fakerapi.it/api/v1/credit_cards?'

# %%
response2 = requests.get(url_api_cards)
resultados = json.loads(response2.text)

# %%
resultados_data = resultados['data']
pd.DataFrame(resultados_data)
# Out:
#                type            number expiration             owner
# 0  American Express  4532709151238180      09/24     Uriah Collins
# 1              Visa  6011041403440371      11/25      Dejuan Marks
# 2        MasterCard  2518511984145877      12/25      Ariane Boehm
# 3              Visa     4485345206105      05/25   Shyanne Corkery
# 4        MasterCard  5167813570199111      10/24      Lois Kerluke
# 5              Visa  4636662388653249      11/24      Darien Hills
# 6        MasterCard  5586878731842076      06/24    Santino Erdman
# 7        MasterCard   341787267602332      04/26  Caleb Morissette
# 8              Visa     4741629244984      07/25  Willard Luettgen
# 9        MasterCard     4556183028528      07/24   Winston Effertz

# %% [markdown]
# ## API de productos

# %%
url_api_products = 'https://fakerapi.it/api/v1/products'

# %%
respo = requests.get(url_api_products)
resul = json.loads(respo.text)

# %%
reslt_data = resul['data']
pd.DataFrame(reslt_data)
# Out:
#    id                          name  \
# 0   1           Qui corrupti id et.
# 1   2      Soluta tenetur et totam.
# 2   3     Et neque veritatis fugit.
# 3   4       Et sit eius voluptatem.
# 4   5    Qui est nostrum eos velit.
# 5   6         Repellat et et iusto.
# 6   7       Soluta rerum magnam ad.
# 7   8        Porro ad nesciunt qui.
# 8   9  Molestiae dolorem hic ipsam.
# 9  10    Qui totam debitis quaerat.
#
#                                          description            ean  \
# 0  Dolore porro itaque soluta quia. Quis voluptas...  3886088733415
# 1  Aspernatur est aut fugiat. Sed voluptates amet...  5522557752591
# 2  Earum assumenda quo aspernatur commodi exceptu...  1044110813036
# 3  Architecto eos distinctio et placeat officiis ...  9481415128588
# 4  Id repellendus iure iusto neque est nemo. Impe...  5881046562241
# 5  Voluptatem est placeat ullam non vero quia. Te...  7760956062431
# 6  Est sed doloremque rerum fugiat vel error nesc...  5121235661318
# 7  Magni corrupti ea non non accusantium ab. Plac...  4054649379757
# 8  Facere tempora accusamus libero nam sed nam li...  4882035272401
# 9  Nihil consectetur quo id impedit quis facilis....  3104752652061
#
#             upc                             image  \
# 0  916725380940  http://placeimg.com/640/480/tech
# 1  070112670275  http://placeimg.com/640/480/tech
# 2  916210170329  http://placeimg.com/640/480/tech
# 3  626415548856  http://placeimg.com/640/480/tech
# 4  121781589583  http://placeimg.com/640/480/tech
# 5  984063114485  http://placeimg.com/640/480/tech
# 6  657656469256  http://placeimg.com/640/480/tech
# 7  476811177458  http://placeimg.com/640/480/tech
# 8  107336134765  http://placeimg.com/640/480/tech
# 9  028468934540  http://placeimg.com/640/480/tech
#
#                                               images    net_price  taxes  \
# 0  [{'title': 'Enim vero in ut quae.', 'descripti...     26293.65     22
# 1  [{'title': 'Sit et et earum porro.', 'descript...  16780138.01     22
# 2  [{'title': 'Quis et dolor ea ipsum.', 'descrip...        10.69     22
# 3  [{'title': 'Sed quae optio et.', 'description'...    231465.16     22
# 4  [{'title': 'Iure tenetur molestiae non.', 'des...        15.35     22
# 5  [{'title': 'Vel ullam harum molestias.', 'desc...       175.28     22
# 6  [{'title': 'Provident fugiat quo atque.', 'des...         0.28     22
# 7  [{'title': 'Veniam eum doloremque et.', 'descr...         7.47     22
# 8  [{'title': 'Dolores nisi nobis animi.', 'descr...     18422.34     22
# 9  [{'title': 'Mollitia sunt nam ea cum.', 'descr...        44.11     22
#
#          price             categories  \
# 0     32078.25              [5, 3, 4]
# 1  20471768.37                 [8, 7]
# 2        13.04              [9, 5, 7]
# 3    282387.50        [8, 1, 9, 3, 4]
# 4        18.73                    [6]
# 5       213.84  [9, 7, 6, 8, 5, 1, 4]
# 6         0.34        [9, 2, 8, 6, 1]
# 7         9.11     [1, 3, 2, 8, 5, 9]
# 8     22475.25              [8, 9, 7]
# 9        53.81        [1, 4, 7, 3, 2]
#
#                                                 tags
# 0  [nihil, sunt, similique, qui, laudantium, ea, ...
# 1  [magnam, quod, officia, libero, rerum, ex, et,...
# 2  [quibusdam, nam, aperiam, reprehenderit, dolor...
# 3  [voluptatem, aspernatur, reprehenderit, distin...
# 4  [veniam, ducimus, deserunt, et, quisquam, maxi...
# 5                  [aut, quia, et, dolorem, dolorem]
# 6  [impedit, nam, dolor, unde, voluptatem, ut, te...
# 7                               [eos, ut, et, velit]
# 8                                     [ad, et, nisi]
# 9  [magni, expedita, ut, ducimus, qui, impedit, e...

# %% [markdown]
# ## API Imagenes

# %%
url_imagenes = 'https://fakerapi.it/api/v1/images'

# %%
response_Imagenes = requests.get(url_imagenes)
resultados_Imagenes = json.loads(response_Imagenes.text)

# %%
data_Imagenes = resultados_Imagenes['data']
pd.DataFrame(data_Imagenes)
# Out:
#                            title  \
# 0  Ipsa in aperiam dolores esse.
# 1      Assumenda illum non quia.
# 2        Enim aut provident eum.
# 3     Rem sint quae illum omnis.
# 4       Iusto enim et aut quasi.
# 5      Molestias dolores ut aut.
# 6     Nihil quis eos aliquid et.
# 7      Sed laboriosam rem ab id.
# 8  Et autem quia quos unde ipsa.
# 9     Et eaque explicabo eos ut.
#
#                                          description  \
# 0  Sed fugit voluptas veritatis assumenda perfere...
# 1  Aspernatur minima ut eos delectus necessitatib...
# 2  Dicta magnam qui dolor itaque. Libero non tota...
# 3  Vero rerum labore qui omnis ex iste. Ut aspern...
# 4  Aut quia reiciendis ut vitae perferendis ex. A...
# 5  Aspernatur non voluptas est. Itaque repudianda...
# 6  Eum cupiditate odio perferendis et praesentium...
# 7  Harum cum sunt ut dolores in asperiores. Eum e...
# 8  Maiores quia aut et non est. Aut praesentium e...
# 9  Delectus qui qui quo aliquid. Et voluptas accu...
#
#                                url
# 0  http://placeimg.com/640/480/any
# 1  http://placeimg.com/640/480/any
# 2  http://placeimg.com/640/480/any
# 3  http://placeimg.com/640/480/any
# 4  http://placeimg.com/640/480/any
# 5  http://placeimg.com/640/480/any
# 6  http://placeimg.com/640/480/any
# 7  http://placeimg.com/640/480/any
# 8  http://placeimg.com/640/480/any
# 9  http://placeimg.com/640/480/any
